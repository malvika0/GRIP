# %% [markdown]
# ## Author - Malvika Arora

# %% [markdown]
# ## GRIP @ The Sparks Foundation

# %% [markdown]
# ## Data Science and Business Analytics Intern

# %% [markdown]
# ## Batch - September 2023

# %% [markdown]
# # Task-1  Predict the percentage of a student based on the number of study hours.

# %% [markdown]
# ### Objective:
#
# - In this task we need to predict the percentage of a student based on the number of study hours.

# %% [markdown]
# Link to download the dataset
#
# https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv

# %%
# Impotant libraries which we will use in this project:-

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# First we will load our dataset for that we will use read_csv which is in https form

url = "https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv"
df = pd.read_csv(url)
pd.set_option('display.max_columns', None)

# %%
# head() will display the first 5 rows of the dataset
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
from IPython import display
display.Image("C:\\Users\\Malvika\\Downloads\\student.jpg")

# %% [markdown]
# ## Data Analysis

# %%
# To check the shape of our dataset

df.shape  # it has 25 rows and 2 columns
# Out:
# (25, 2)

# %%
# To check the size of our dataset

df.size  # the total size
# Out:
# 50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes

# %%
# describe() provides statistical measures such as count, mean, standard deviation, minimum, quartiles, and maximum values for each numeric column in the DataFrame.
df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
df.isnull().sum()  # this will check the null values in the dataset 0 mean no null value
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %%
# To check for duplicate values

duplicate_count = df.duplicated().sum()
print(duplicate_count)
# Out:
# 0

# %%
# To view the column names in the dataset we will use 

df.columns
# Out:
# Index(['Hours', 'Scores'], dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Data Visualization

# %%
# Let's visualize our data

x = df["Hours"]
y = df["Scores"]

# %%
plt.figure(figsize=(10, 5))
plt.bar(x, y, color="g")
plt.title('Line Plot of Scores Over Hours')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.grid(True)
plt.show()

# %%
# 5. Box Plot
plt.figure(figsize=(8, 4))
plt.boxplot(y)
plt.title('Box Plot of Scores')
plt.ylabel('Scores')
plt.grid(axis='y')
plt.show()

# %%
# 5. Box Plot
plt.figure(figsize=(8, 4))
plt.boxplot(x)
plt.title('Box Plot of Hours')
plt.ylabel('Hours')
plt.grid(axis='x')
plt.show()

# %% [markdown]
# We can see our data as no outliers

# %%
plt.figure(figsize=(10, 5))
plt.scatter(x, y, marker='o', linestyle='-', color="black")
plt.title('Line Plot of Scores Over Hours')
plt.xlabel('Hours')
plt.ylabel('Scores')
plt.grid(True)
plt.show()

# %% [markdown]
# __From the above scatter plot there looks to be correlation between the 'Scores' and 'Hours', Lets plot a regression line to confirm the correlation.__

# %% [markdown]
# ### Regression Plot

# %%
plt.figure(figsize=(10, 5))
sns.regplot(x=df["Hours"], y=df["Scores"])
plt.title('Regression Plot',size=20)
plt.ylabel('Marks Percentage', size=12)
plt.xlabel('Hours Studied', size=12)
plt.show()
print(df.corr())
# Out:
#            Hours    Scores
# Hours   1.000000  0.976191
# Scores  0.976191  1.000000

# %% [markdown]
# __As we can see Hours and Scores are positively correlated as hours increases scores are also increasing__

# %% [markdown]
# # Training the model

# %%
# Model Prediction -

from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import accuracy_score, mean_absolute_error, mean_squared_error

# %%
# Defining X and Y from the Data

X = df.iloc[:, :-1].values  
Y = df.iloc[:, 1].values

# %%
X
# Out:
# array([[2.5],
#        [5.1],
#        [3.2],
#        [8.5],
#        [3.5],
#        [1.5],
#        [9.2],
#        [5.5],
#        [8.3],
#        [2.7],
#        [7.7],
#        [5.9],
#        [4.5],
#        [3.3],
#        [1.1],
#        [8.9],
#        [2.5],
#        [1.9],
#        [6.1],
#        [7.4],
#        [2.7],
#        [4.8],
#        [3.8],
#        [6.9],
#        [7.8]])

# %%
Y
# Out:
# array([21, 47, 27, 75, 30, 20, 88, 60, 81, 25, 85, 62, 41, 42, 17, 95, 30,
#        24, 67, 69, 30, 54, 35, 76, 86], dtype=int64)

# %%
# Split the data into training and testing sets

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=0) # 24% data for testing purpose

# %%
X_train
# Out:
# array([[3.8],
#        [1.9],
#        [7.8],
#        [6.9],
#        [1.1],
#        [5.1],
#        [7.7],
#        [3.3],
#        [8.3],
#        [9.2],
#        [6.1],
#        [3.5],
#        [2.7],
#        [5.5],
#        [2.7],
#        [8.5],
#        [2.5],
#        [4.8],
#        [8.9],
#        [4.5]])

# %%
X_test
# Out:
# array([[1.5],
#        [3.2],
#        [7.4],
#        [2.5],
#        [5.9]])

# %%
Y_train
# Out:
# array([35, 24, 86, 76, 17, 47, 85, 42, 81, 88, 67, 30, 25, 60, 30, 75, 21,
#        54, 95, 41], dtype=int64)

# %%
Y_test
# Out:
# array([20, 27, 69, 30, 62], dtype=int64)

# %%
Model = LinearRegression()

# %%
Model
# Out:
# LinearRegression()

# %%
Model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
y_pred = Model.predict(X_test)

# %%
y_pred
# Out:
# array([16.88414476, 33.73226078, 75.357018  , 26.79480124, 60.49103328])

# %%
prediction = pd.DataFrame({'Hours': [i[0] for i in X_test], 'Predicted Marks': [k for k in y_pred]})

# %%
prediction
# Out:
#    Hours  Predicted Marks
# 0    1.5        16.884145
# 1    3.2        33.732261
# 2    7.4        75.357018
# 3    2.5        26.794801
# 4    5.9        60.491033

# %%
compare_scores = pd.DataFrame({'Actual Marks': Y_test, 'Predicted Marks': y_pred})
compare_scores
# Out:
#    Actual Marks  Predicted Marks
# 0            20        16.884145
# 1            27        33.732261
# 2            69        75.357018
# 3            30        26.794801
# 4            62        60.491033

# %% [markdown]
# # Visually Comparing the Predicted Marks with the Actual Marks

# %%
plt.scatter(x=X_test, y=Y_test, color='blue')
plt.plot(X_test, y_pred, color='Black')
plt.title('Actual vs Predicted', size=20)
plt.ylabel('Marks Percentage', size=12)
plt.xlabel('Hours Studied', size=12)
plt.show()

# %% [markdown]
# # What will be the predicted score of a student if he/she studies for 9.25 hrs/ day?

# %%
hours = [9.25]
answer = Model.predict([hours])
print(f"No of Hours = {hours}")
print(f"Predicted Score = {answer}")
# Out:
# No of Hours = [9.25]
# Predicted Score = [93.69173249]

# %% [markdown]
# __According to the regression model if a student studies for 9.25 hours a day he/she is likely to score 93.89 marks.__

# %% [markdown]
# # Evaluating the model

# %% [markdown]
# The final step is to evaluate the performance of algorithm. This step is particularly important to compare how well different algorithms perform on a particular dataset. For simplicity here, we have chosen the mean square error. There are many such metrics.

# %%
# Calculating the accuracy of the model

print('Mean absolute error: ',mean_absolute_error(Y_test,y_pred))
# Out:
# Mean absolute error:  4.183859899002975

# %% [markdown]
# __Small value of Mean absolute error states that the chances of error or wrong forecasting through the model are very less.__

# %% [markdown]
# # Conclusion

# %% [markdown]
# __According to the regression model if a student studies for 9.25 hours a day he/she is likely to score 93.89 marks.__
